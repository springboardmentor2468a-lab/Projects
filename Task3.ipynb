# %% [markdown]
# <a href="https://colab.research.google.com/github/springboardmentor2468a-lab/Projects/blob/Thanuja-Gogada/Task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **WEEK 3**

# %% [markdown]
# **Univariate and Bivariate Visual Analysis**

# %%
from google.colab import files
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
uploaded = files.upload()
df = pd.read_csv(list(uploaded.keys())[0])
# Out:
#      <input type="file" id="files-bfbbee88-13ba-44e6-b4bf-d32670e7088b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bfbbee88-13ba-44e6-b4bf-d32670e7088b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Separate numerical and categorical columns

# %%
num_cols = df.select_dtypes(include=['int64','float64']).columns
cat_cols = df.select_dtypes(include=['object','bool']).columns

# %% [markdown]
#  **Univariate Analysis**

# %% [markdown]
#  Histograms for numerical columns

# %%
df[num_cols].hist(figsize=(12,8), bins=20, edgecolor="black", color="skyblue")
plt.suptitle("Histograms of Numerical Columns")
plt.show()

# %% [markdown]
#  Boxplots for numnerical columns

# %%
df[num_cols].plot(kind="box", subplots=True, layout=(2,2), figsize=(12,8), sharex=False, sharey=False)
plt.suptitle("Boxplots of Numerical Columns")
plt.show()

# %% [markdown]
# Bar Charts for categorical columns

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm

colors = cm.tab10.colors
rows = (len(cat_cols) + 1) // 2
fig, axes = plt.subplots(rows, 2, figsize=(12, 5*rows))
axes = axes.flatten()

for i, col in enumerate(cat_cols):
    df[col].value_counts().plot(kind="bar", color=colors[i % 10], ax=axes[i], edgecolor="black")
    axes[i].set_title(f"Bar Chart of {col}")
    axes[i].set_ylabel("Count")
for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# Line Plots for numerical columns

# %%
axes = df[num_cols].plot(
    subplots=True,
    layout=(len(num_cols), 1),
    figsize=(12, 3*len(num_cols)),
    legend=False
)
for ax, col in zip(axes.flatten(), num_cols):
    ax.set_title(f"Line Plot of {col}")
    ax.set_xlabel("Index")
    ax.set_ylabel(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# Heatmap (correlation of numerical columns)

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df[num_cols].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Heatmap of Numerical Columns Correlation")
plt.show()

# %% [markdown]
# **OBSERVATIONS**

# %% [markdown]
# Certain age groups have noticeably higher screen time, indicating teens spend more time on devices than pre-teens.

# %% [markdown]
# Smartphones are the most commonly used primary device, while TV and laptops are less frequent.

# %% [markdown]
# There are categories with very few users (like certain devices or age bands), which could be considered outliers.

# %% [markdown]
# Most students reported health effects related to eyes and posture, suggesting a link to prolonged screen usage.

# %% [markdown]
# Weekday vs weekend screen time shows a clear difference, with higher usage on weekends.

# %% [markdown]
# Portable devices (<30”) are more popular than large devices (>30”), showing convenience matters more than screen size.

# %% [markdown]
# Some categorical variables, like location (urban/rural), show uneven distribution, hinting at accessibility differences.

# %% [markdown]
# **HEATMAP OBSERVATIONS**

# %% [markdown]
# Strong positive correlation between screen time and eye strain indicates prolonged usage affects vision

# %% [markdown]
# Weak correlation between age and device type suggests device preference doesn’t vary much with age.

# %% [markdown]
# Negative correlation between outdoor activity and screen time shows more outdoor activity reduces device usage.

# %% [markdown]
# Health impact metrics like posture and sleep disturbance show moderate correlation with daily screen time.
