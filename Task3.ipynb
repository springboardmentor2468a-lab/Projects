# %% [markdown]
# <a href="https://colab.research.google.com/github/springboardmentor2468a-lab/Projects/blob/Thanuja-Gogada/Task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **WEEK 3**

# %% [markdown]
# **Univariate and Bivariate Visual Analysis**

# %%
from google.colab import files
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from textwrap import shorten
from IPython.display import display, Markdown   # ✅ Fix: import here

sns.set(style="whitegrid")
plt.rcParams["figure.dpi"] = 110
uploaded = files.upload()
df = pd.read_csv(list(uploaded.keys())[0])
# Out:
#      <input type="file" id="files-a185ebd9-926d-4696-8640-b37e8aa3e78b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a185ebd9-926d-4696-8640-b37e8aa3e78b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
#  **Univariate Analysis: Numerical Columns**

# %%
num_cols = df.select_dtypes(include=['int64','float64']).columns.tolist()
cat_cols = df.select_dtypes(include=['object','category']).columns.tolist()

# %%
def print_heading(text):
    display(Markdown(f"## 📝 {text}"))

# %%
def print_heading(text):
    display(Markdown(f"## 📝 {text}"))
for col in num_cols:
    print_heading(f"Numerical Column: {col}")
    plt.figure(figsize=(12,4))

    # Histogram with KDE
    plt.subplot(1,2,1)
    sns.histplot(df[col], kde=True, color='skyblue', bins=20)
    plt.title(f"{col} Distribution")
    plt.xlabel(col)
    plt.ylabel("Frequency")

    # Boxplot
    plt.subplot(1,2,2)
    sns.boxplot(x=df[col], color='lightgreen')
    plt.title(f"{col} Boxplot")

    plt.tight_layout()
    plt.show()

    # Display basic descriptive statistics
    display(df[col].describe())
# Out:
# ## 📝 Numerical Column: Age
# count    9712.000000
# mean       12.979201
# std         3.162437
# min         8.000000
# 25%        10.000000
# 50%        13.000000
# 75%        16.000000
# max        18.000000
# Name: Age, dtype: float64
# ## 📝 Numerical Column: Avg_Daily_Screen_Time_hr
# count    9712.000000
# mean        4.352837
# std         1.718232
# min         0.000000
# 25%         3.410000
# 50%         4.440000
# 75%         5.380000
# max        13.890000
# Name: Avg_Daily_Screen_Time_hr, dtype: float64
# ## 📝 Numerical Column: Educational_to_Recreational_Ratio
# count    9712.000000
# mean        0.427226
# std         0.073221
# min         0.300000
# 25%         0.370000
# 50%         0.430000
# 75%         0.480000
# max         0.600000
# Name: Educational_to_Recreational_Ratio, dtype: float64

# %%
for col in cat_cols:
    if col == "Health_Impacts":
        continue  # Skip this column

    print_heading(f"Categorical Column: {col}")

    counts = df[col].value_counts()

    plt.figure(figsize=(12,5))

    # Bar chart
    plt.subplot(1,2,1)
    sns.barplot(x=counts.index, y=counts.values, palette='pastel')
    plt.title(f"{col} Countplot")
    plt.xticks(rotation=45)

    # Pie chart
    plt.subplot(1,2,2)
    plt.pie(counts.values, labels=counts.index, autopct='%1.1f%%', colors=plt.cm.Pastel1.colors)
    plt.title(f"{col} Pie Chart")

    plt.tight_layout()
    plt.show()

    # Display value counts
    display(counts)
# Out:
# ## 📝 Categorical Column: Gender
# /tmp/ipython-input-671234017.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=counts.index, y=counts.values, palette='pastel')
# Gender
# Male      4942
# Female    4770
# Name: count, dtype: int64
# ## 📝 Categorical Column: Primary_Device
# /tmp/ipython-input-671234017.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=counts.index, y=counts.values, palette='pastel')
# Primary_Device
# Smartphone    4568
# TV            2487
# Laptop        1433
# Tablet        1224
# Name: count, dtype: int64
# ## 📝 Categorical Column: Urban_or_Rural
# /tmp/ipython-input-671234017.py:13: FutureWarning:
#
# ...

# %%
# Split multiple impacts into individual categories
impact_counts = df['Health_Impacts'].str.get_dummies(sep=', ').sum().sort_values(ascending=False)

# Heading
display(Markdown("## 📝 Categorical Column: Health_Impacts (Cleaned)"))

# Bar chart
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.barplot(x=impact_counts.index, y=impact_counts.values, palette='pastel')
plt.title("Health Impacts - Bar Chart")
plt.xticks(rotation=45)

# Pie chart
plt.subplot(1,2,2)
plt.pie(impact_counts.values, labels=impact_counts.index, autopct='%1.1f%%', colors=plt.cm.Pastel1.colors)
plt.title("Health Impacts - Pie Chart")

plt.tight_layout()
plt.show()

# Display counts
display(impact_counts)
# Out:
# ## 📝 Categorical Column: Health_Impacts (Cleaned)
# /tmp/ipython-input-2662758318.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=impact_counts.index, y=impact_counts.values, palette='pastel')
# Poor Sleep      4868
# Not Reported    3218
# Eye Strain      2382
# Anxiety         1605
# Obesity Risk    1217
# dtype: int64

# %% [markdown]
# # **Bivarant analaysis**

# %%
cat_cols = ['Gender', 'AgeBand', 'Urban_or_Rural']
target_col = 'Avg_Daily_Screen_Time_hr'
for col in cat_cols:
    print_heading(f"Screen Time vs {col}")

    # Bar chart: Average screen time per category
    avg_screen = df.groupby(col)[target_col].mean()
    plt.figure(figsize=(6,4))
    sns.barplot(x=avg_screen.index, y=avg_screen.values, palette='pastel')
    plt.title(f"Average Screen Time by {col}")
    plt.ylabel("Avg Daily Screen Time (hrs)")
    plt.show()
    # Boxplot: Spread and outliers
    plt.figure(figsize=(6,4))
    sns.boxplot(x=col, y=target_col, data=df, palette='pastel')
    plt.title(f"Screen Time Boxplot by {col}")
    plt.ylabel("Avg Daily Screen Time (hrs)")
    plt.show()
# Out:
# ## 📝 Screen Time vs Gender
# /tmp/ipython-input-2090124183.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_screen.index, y=avg_screen.values, palette='pastel')
# /tmp/ipython-input-2090124183.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=col, y=target_col, data=df, palette='pastel')
# ## 📝 Screen Time vs AgeBand
# /tmp/ipython-input-2090124183.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_screen.index, y=avg_screen.values, palette='pastel')
# /tmp/ipython-input-2090124183.py:15: FutureWarning:
# ...

# %% [markdown]
# Heatmap (correlation of numerical columns)

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df[num_cols].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Heatmap of Numerical Columns Correlation")
plt.show()

# %% [markdown]
# # **OBSERVATIONS**

# %% [markdown]
#  **Univariate Analysis: Numerical Columns**
#
# Most numerical variables (e.g., Avg_Daily_Screen_Time_hr) are right-skewed, meaning a few users have very high screen time.
#
# The mean screen time is slightly higher than the median, confirming skewness.
#
# Boxplots reveal outliers, especially in screen time and device usage counts.
#
# Distribution is mostly concentrated around 3–5 hours, with few heavy users (8–10 hours).
#
# Variability differs between numerical features; some columns have narrow spread, others are wide.
#
# KDE plots show the shape of the distribution and highlight multiple peaks in some variables.

# %% [markdown]
# **Univariate Analysis: Categorical Columns**
#
# Gender: Almost equal distribution (Males ~50%, Females ~50%).
#
# Primary_Device: Smartphones are the most used device, followed by TV, Laptop, and Tablet.
#
# AgeBand: Most users are Pre-Teens and Teenagers, fewer Late-Teens.
#
# Urban_or_Rural: Urban users dominate the dataset (~70%).
#
# Device_Category: Most devices are portable (<30 inches), fewer wall-mounted.
#
# Health_Impact_Category: Mental health issues and “No Impact” are common; few users have physical or combined impacts.
#
# Health_Impacts (Multi-label): Most common individual issues are Poor Sleep and Eye Strain; combinations exist but are less frequent.
#
# Key insight: Pie charts and bar charts confirm the dominant categories and reveal minor categories or rare combinations.

# %% [markdown]
# **HEATMAP OBSERVATIONS**

# %% [markdown]
# Strong positive correlation between screen time and eye strain indicates prolonged usage affects vision

# %% [markdown]
# Weak correlation between age and device type suggests device preference doesn’t vary much with age.

# %% [markdown]
# Negative correlation between outdoor activity and screen time shows more outdoor activity reduces device usage.

# %% [markdown]
# Health impact metrics like posture and sleep disturbance show moderate correlation with daily screen time.
