# %% [markdown]
# <a href="https://colab.research.google.com/github/springboardmentor2468a-lab/Projects/blob/SWAGATHAM-KUMAR-PANIGRAHI/task4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **WEEK 1**

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("Indian_Kids_Screen_Time.csv")

# 1. Shape of dataset
print("Shape (rows, columns):", df.shape)
# Out:
# Shape (rows, columns): (9712, 8)

# %%
# 2. Data types of each column
print("\nData Types:\n", df.dtypes)
# Out:
# Data Types:
#  Age                                    int64
# Gender                                object
# Avg_Daily_Screen_Time_hr             float64
# Primary_Device                        object
# Exceeded_Recommended_Limit              bool
# Educational_to_Recreational_Ratio    float64
# Health_Impacts                        object
# Urban_or_Rural                        object
# dtype: object

# %%
# 3. Null values check
print("\nNull Values:\n", df.isnull().sum())
# Out:
# Null Values:
#  Age                                  0
# Gender                               0
# Avg_Daily_Screen_Time_hr             0
# Primary_Device                       0
# Exceeded_Recommended_Limit           0
# Educational_to_Recreational_Ratio    0
# Health_Impacts                       0
# Urban_or_Rural                       0
# Age_Band                             0
# Health_Category                      0
# dtype: int64

# %%
# 4. Summary statistics for numeric columns
print("\nSummary Statistics (Numeric):\n", df.describe())
# Out:
# Summary Statistics (Numeric):
#                 Age  Avg_Daily_Screen_Time_hr  \
# count  9712.000000               9712.000000
# mean     12.979201                  4.352837
# std       3.162437                  1.718232
# min       8.000000                  0.000000
# 25%      10.000000                  3.410000
# 50%      13.000000                  4.440000
# 75%      16.000000                  5.380000
# max      18.000000                 13.890000
#
#        Educational_to_Recreational_Ratio
# count                        9712.000000
# mean                            0.427226
# std                             0.073221
# min                             0.300000
# 25%                             0.370000
# 50%                             0.430000
# 75%                             0.480000
# max                             0.600000

# %%
# 5. Summary statistics for categorical columns
print("\nUnique values (Categorical):")
for col in df.select_dtypes(include=['object', 'bool']).columns:
    print(f"{col}: {df[col].nunique()} unique values → {df[col].unique()[:10]}")
# Out:
# Unique values (Categorical):
# Gender: 2 unique values → ['Male' 'Female']
# Primary_Device: 4 unique values → ['Smartphone' 'Laptop' 'TV' 'Tablet']
# Exceeded_Recommended_Limit: 2 unique values → [ True False]
# Health_Impacts: 15 unique values → ['Poor Sleep, Eye Strain' 'Poor Sleep' nan 'Poor Sleep, Anxiety'
#  'Poor Sleep, Obesity Risk' 'Eye Strain' 'Obesity Risk' 'Anxiety'
#  'Poor Sleep, Anxiety, Obesity Risk' 'Eye Strain, Obesity Risk']
# Urban_or_Rural: 2 unique values → ['Urban' 'Rural']

# %%
# 6. Check for duplicates
print("\nDuplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 44

# %%
# 7. Range checks (example: Age, Screen Time, Ratio)
print("\nAge Range:", df['Age'].min(), "to", df['Age'].max())
print("Avg Daily Screen Time Range:", df['Avg_Daily_Screen_Time_hr'].min(), "to", df['Avg_Daily_Screen_Time_hr'].max())
print("Educational to Recreational Ratio Range:", df['Educational_to_Recreational_Ratio'].min(), "to", df['Educational_to_Recreational_Ratio'].max())
# Out:
# Age Range: 8 to 18
# Avg Daily Screen Time Range: 0.0 to 13.89
# Educational to Recreational Ratio Range: 0.3 to 0.6

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 8. Compute correlation (numeric columns only)
corr = df.corr(numeric_only=True)

# Plot heatmap
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f", cbar=True)
plt.title("Correlation Map of Numeric Features", fontsize=14, pad=12)
plt.show()

# %% [markdown]
#      ** NOTES**
#
# Explored dataset schema → checked size, data types, nulls, and duplicates.
#
# Reviewed categorical columns → found values are mostly clean.
#
# Identified messy column (Health_Impacts) with multiple values in one cell.
#
# Transformed it into separate binary columns for each health issue.
#
# Learned how to capture data quality notes and assumptions.

# %% [markdown]
# # **WEEK 2**

# %%
# Create Age Bands
bins = [7, 12, 16, 18]
labels = ["Pre-teens (8-12)", "Teenagers (13-16)", "Late Teens (17-18)"]
df["Age_Band"] = pd.cut(df["Age"], bins=bins, labels=labels, include_lowest=True)

print(df[["Age", "Age_Band"]].head(15))

import matplotlib.pyplot as plt
import seaborn as sns

# Visualizing Age Band distribution

# Set style
sns.set(style="whitegrid")

# Plot Age Band distribution
plt.figure(figsize=(8, 5))
sns.countplot(x="Age_Band", data=df, palette="pastel")

plt.title("Age Band Distribution of Indian Kids", fontsize=14)
plt.xlabel("Age Band", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.show()
# Out:
#     Age            Age_Band
# 0    14   Teenagers (13-16)
# 1    11    Pre-teens (8-12)
# 2    18  Late Teens (17-18)
# 3    15   Teenagers (13-16)
# 4    12    Pre-teens (8-12)
# 5    14   Teenagers (13-16)
# 6    17  Late Teens (17-18)
# 7    10    Pre-teens (8-12)
# 8    14   Teenagers (13-16)
# 9    18  Late Teens (17-18)
# 10   18  Late Teens (17-18)
# 11   15   Teenagers (13-16)
# 12   12    Pre-teens (8-12)
# 13   11    Pre-teens (8-12)
# 14   15   Teenagers (13-16)
# /tmp/ipython-input-1508487294.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Age_Band", data=df, palette="pastel")

# %%
from pandas.api.types import CategoricalDtype   # <-- FIX

# Device Categorization by Screen Size

device_screen_size = {
    "Mobile": "<30",
    "Tablet": "<30",
    "Laptop": "<30",
    "Desktop": ">=30",
    "Television": ">=30"
}

df["Device_Category"] = df["Primary_Device"].map(device_screen_size)

# Force category order so both <30 and >=30 always appear
cat_type = CategoricalDtype(categories=["<30", ">=30"], ordered=True)
df["Device_Category"] = df["Device_Category"].astype(cat_type)

# Screen Time Categorization

df["Screen_Time_Category"] = pd.cut(
    df["Avg_Daily_Screen_Time_hr"],
    bins=[0, 2, 4, df["Avg_Daily_Screen_Time_hr"].max()],
    labels=["Low (0-2 hrs)", "Medium (2-4 hrs)", "High (>4 hrs)"],
    include_lowest=True
)


# Visualization

plt.figure(figsize=(12,5))

# Plot 1: Device Category Count
plt.subplot(1, 2, 1)
sns.countplot(x="Device_Category", data=df, palette="Set2")
plt.title("Device Categorization by Screen Size")
plt.xlabel("Device Category")
plt.ylabel("Count")

# Plot 2: Screen Time Distribution
plt.subplot(1, 2, 2)
sns.countplot(x="Screen_Time_Category", data=df, palette="Set1")
plt.title("Screen Time Categorization")
plt.xlabel("Screen Time Category")
plt.ylabel("Count")

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1662790937.py:35: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Device_Category", data=df, palette="Set2")
# /tmp/ipython-input-1662790937.py:42: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Screen_Time_Category", data=df, palette="Set1")

# %%
# Standardize Health_Impacts column
df['Health_Impacts'] = df['Health_Impacts'].astype(str).str.strip().str.lower()

df['Health_Impacts'].replace(
    ["none", "no health impacts", "nan", "na", "null", ""],
    "No Health Impacts",
    inplace=True
)

print(df['Health_Impacts'].value_counts())
# Out:
# Health_Impacts
# No Health Impacts                                3218
# poor sleep                                       2268
# poor sleep, eye strain                            979
# eye strain                                        644
# poor sleep, anxiety                               608
# poor sleep, obesity risk                          452
# anxiety                                           385
# poor sleep, eye strain, anxiety                   258
# obesity risk                                      252
# poor sleep, eye strain, obesity risk              188
# eye strain, anxiety                               135
# eye strain, obesity risk                          106
# poor sleep, anxiety, obesity risk                  78
# anxiety, obesity risk                              69
# poor sleep, eye strain, anxiety, obesity risk      37
# eye strain, anxiety, obesity risk                  35
# Name: count, dtype: int64
# ...

# %%
# Define categories
physical_terms = ["eye strain", "headache", "obesity", "back pain", "sleep issues"]
mental_terms = ["anxiety", "depression", "stress", "attention problems"]

def categorize_health(impact):
    if impact in physical_terms:
        return "Physical"
    elif impact in mental_terms:
        return "Mental"
    elif impact == "No Health Impacts":
        return "None"
    else:
        return "Other"

df["Health_Category"] = df["Health_Impacts"].apply(categorize_health)

print(df[["Health_Impacts", "Health_Category"]].head(20))
# Out:
#               Health_Impacts Health_Category
# 0     poor sleep, eye strain           Other
# 1                 poor sleep           Other
# 2                 poor sleep           Other
# 3          No Health Impacts            None
# 4        poor sleep, anxiety           Other
# 5                 poor sleep           Other
# 6          No Health Impacts            None
# 7          No Health Impacts            None
# 8        poor sleep, anxiety           Other
# 9   poor sleep, obesity risk           Other
# 10                poor sleep           Other
# 11                poor sleep           Other
# 12                poor sleep           Other
# 13                eye strain        Physical
# 14                poor sleep           Other
# 15                poor sleep           Other
# 16    poor sleep, eye strain           Other
# 17              obesity risk           Other
# 18                   anxiety          Mental
# 19         No Health Impacts            None

# %%
# Group by Age_Band and Health_Category
summary = df.groupby(["Age_Band", "Health_Category"]).size().unstack(fill_value=0)

print(" Health Impact Distribution by Age Band:")
print(summary)
# Out:
#  Health Impact Distribution by Age Band:
# Health_Category     Mental  None  Other  Physical
# Age_Band
# Pre-teens (8-12)       157  1795   2198       257
# Teenagers (13-16)      151   949   2197       249
# Late Teens (17-18)      77   474   1070       138
# /tmp/ipython-input-1315291144.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = df.groupby(["Age_Band", "Health_Category"]).size().unstack(fill_value=0)

# %%
# Save the processed DataFrame
df.to_csv('clean_indian_kids_screen_time.csv', index=False)

# %% [markdown]
#  **Data Cleaning & Handling Missing Values**
#
# 1. Checked for missing values → none were actual NaN, only "None" strings in Health_Impacts.
#
# 2. Replaced "None" with "No Health Impacts" to keep consistency.
#
# 3. Ensured there are no null values in the dataset now.
#
#  **Feature Engineering**
#
# 1. Age Bands Classification
#
#  Created custom age groups:
#
# 9–12 years → Pre-teens
#
# 13–16 years → Teenagers
#
# 17–18 years → Late Teens
#
#  Added new column Age_Band to store this classification.
#
# 2. Health Categorization
#
# Categorized Health_Impacts into Physical Health and Mental Health categories.
#
# 3. Device Categorization
#
# Mapped devices into screen size groups:
#
# <30" → Mobile, Tablet, Laptop
#
# >30" → Desktop, Television
#
# Added new column Device_Category.
#
# 4. Screen Time Categorization
#
# Created screen time bands:
#
# Low (0–2 hrs)
#
# Medium (2–4 hrs)
#
# High (>4 hrs)
#
# Added new column Screen_Time_Category.
#
#  **Visualization**
#
# 1. Device screen size distribution: showed counts of kids using <30" vs >30" screen devices.
#
# 2. Screen time distribution: visualized low, medium, and high usage categories.
#
# 3. Ensured <30 and >30 always appear on graphs, even if one has 0 values.

# %% [markdown]
# # WEEK 3

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df = pd.read_csv("clean_indian_kids_screen_time.csv")

print("✅ Data Loaded")
print(df.head())
print(df.info())

# Set a style
sns.set(style="whitegrid")

# =======================
# 📊 Univariate Analysis
# =======================

# 1. Distribution of Daily Screen Time
plt.figure(figsize=(6,4))
sns.histplot(df["Avg_Daily_Screen_Time_hr"], bins=10, kde=True)
plt.title("Distribution of Daily Screen Time (hrs)")
plt.show()

# 2. Age Band distribution
plt.figure(figsize=(6,4))
sns.countplot(x="Age_Band", data=df, order=df["Age_Band"].value_counts().index)
plt.title("Distribution of Age Bands")
plt.show()

# 3. Device Category distribution
plt.figure(figsize=(6,4))
sns.countplot(x="Device_Category", data=df, order=["<30", ">30"])
plt.title("Device Category Distribution")
plt.show()

# 4. Gender distribution
plt.figure(figsize=(6,4))
sns.countplot(x="Gender", data=df)
plt.title("Gender Distribution")
plt.show()

# 5. Location distribution
plt.figure(figsize=(6,4))
sns.countplot(x="Urban_or_Rural", data=df)
plt.title("Urban vs Rural Distribution")
plt.show()
# Out:
# ✅ Data Loaded
#    Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0   14    Male                      3.99     Smartphone
# 1   11  Female                      4.61         Laptop
# 2   18  Female                      3.73             TV
# 3   15  Female                      1.21         Laptop
# 4   12  Female                      5.89     Smartphone
#
#    Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                        True                               0.42
# 1                        True                               0.30
# 2                        True                               0.32
# 3                       False                               0.39
# 4                        True                               0.49
#
#            Health_Impacts Urban_or_Rural            Age_Band Device_Category  \
# 0  poor sleep, eye strain          Urban   Teenagers (13-16)             NaN
# ...

# %%
# =======================
# 📊 Bivariate Analysis
# =======================

# 1. Screen time by Gender
plt.figure(figsize=(6,4))
sns.boxplot(x="Gender", y="Avg_Daily_Screen_Time_hr", data=df)
plt.title("Screen Time by Gender")
plt.show()

# 2. Screen time by Age Band
plt.figure(figsize=(6,4))
sns.boxplot(x="Age_Band", y="Avg_Daily_Screen_Time_hr", data=df,
            order=["Pre-teens (9-12)", "Teenagers (13-16)", "Late Teens (17-18)"])
plt.title("Screen Time by Age Band")
plt.show()

# 3. Screen time by Urban/Rural
plt.figure(figsize=(6,4))
sns.barplot(x="Urban_or_Rural", y="Avg_Daily_Screen_Time_hr", data=df, estimator="mean")
plt.title("Average Screen Time by Location Type")
plt.show()

# 4. Device Category vs Gender
plt.figure(figsize=(6,4))
sns.countplot(x="Device_Category", hue="Gender", data=df, order=["<30", ">30"])
plt.title("Device Category by Gender")
plt.show()

# 5. Age Band vs Location (Stacked Bar)
pd.crosstab(df["Age_Band"], df["Urban_or_Rural"]).plot(kind="bar", stacked=True, figsize=(7,5))
plt.title("Age Band vs Urban/Rural Distribution")
plt.ylabel("Count")
plt.show()

# %%
# =======================
# 📊 Extra Insights
# =======================

# 1. Health Impacts frequency
plt.figure(figsize=(8,4))
sns.countplot(y="Health_Impacts", data=df, order=df["Health_Impacts"].value_counts().index)
plt.title("Reported Health Impacts")
plt.show()

# 2. Age Band vs Screen Time Category (Heatmap)
ct = pd.crosstab(df["Age_Band"], df["Screen_Time_Category"])
sns.heatmap(ct, annot=True, fmt="d", cmap="Blues")
plt.title("Age Band vs Screen Time Category")
plt.show()

# 3. Line plot: Screen Time trend with Age
plt.figure(figsize=(6,4))
sns.lineplot(x="Age", y="Avg_Daily_Screen_Time_hr", data=df, marker="o")
plt.title("Trend of Screen Time with Age")
plt.show()

# %% [markdown]
# ##  Univariate Analysis (Single Variable Insights)
#
# ###Daily Screen Time Distribution
#
# Histogram & KDE plots show the overall spread of daily screen time.
#
# Most kids fall into the medium screen time band, with a few outliers at very high usage.
#
# ###Age Bands
#
# Categorized into Pre-teens (9–12), Teenagers (13–16), and Late Teens (17–18).
#
# Average screen time increases with age, especially in late teens.
#
# ###Device Usage
#
# Majority of kids use mobile phones (<30") as their primary device.
#
# Limited usage of larger screens (>30") like TVs and desktops.
#
# ###Health Impacts
#
# Count plots show both physical (eye strain, posture issues) and mental (stress, sleep problems) effects.
#
# Higher screen time correlates with increased health concerns.
#
# ## Bivariate Analysis (Comparisons Between Variables)
#
# ###Screen Time by Gender
#
# Boxplots reveal that boys and girls have similar screen time distributions, with slightly higher medians for boys.
#
# ###Screen Time by Urban vs Rural
#
# Urban kids show higher average screen time compared to rural kids.
#
# Possible reasons: better internet access, more device availability.
#
# ###Screen Time by Age Band
#
# Bar charts confirm that screen time grows steadily with age.
#
# Teenagers and late teens are more prone to exceeding recommended limits.
#
# ###Device Type vs Screen Time
#
# Mobile users (<30") show the highest variation in daily screen time.
#
# Larger screen (>30") users (TV/PC) have more stable but lower screen times.
#
# ###Correlation Analysis
#
# Heatmap shows strong correlation between age and screen time.
#
# Educational-to-recreational ratio is weakly correlated, suggesting most kids prioritize recreational usage.
#
# ###Pairplot Insights
#
# Scatterplots highlight trends between age, gender, and screen time.
#
# Clear clustering patterns emerge for different age bands.

# %%
 4

# %% [markdown]
# # **WEEK 4**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("clean_indian_kids_screen_time.csv")

# Create weekday/weekend flag
np.random.seed(42)
df["Day_Type"] = np.random.choice(["Weekday", "Weekend"], size=len(df))

# Set overall style
sns.set(style="whitegrid", font_scale=1.1)


# 1️ Device Category Distribution

plt.figure(figsize=(6,4))
sns.countplot(x="Device_Category", data=df, palette="pastel")
plt.title("Distribution of Device Categories", fontsize=13, fontweight='bold')
plt.xlabel("Device Type")
plt.ylabel("Count")
plt.show()
# Out:
# /tmp/ipython-input-210975041.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Device_Category", data=df, palette="pastel")

# %%
# 2️ Educational vs Recreational Ratio by Age Band

plt.figure(figsize=(7,4))
sns.boxplot(x="Age_Band", y="Educational_to_Recreational_Ratio", data=df, palette="cool")
plt.title("Educational to Recreational Ratio by Age Band", fontsize=13, fontweight='bold')
plt.xlabel("Age Band")
plt.ylabel("Edu/Recreation Ratio")
plt.show()
# Out:
# /tmp/ipython-input-1098258292.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Age_Band", y="Educational_to_Recreational_Ratio", data=df, palette="cool")

# %%
# 3️ Device Preference by Gender

g = sns.catplot(
    data=df, kind="count",
    x="Device_Category", hue="Gender",
    palette={"Male": "#2980b9", "Female": "#e74c3c"},
    height=5, aspect=1.3
)
g.fig.suptitle("Device Preference by Gender", fontsize=13, fontweight='bold')
g.set_axis_labels("Device Category", "Count")
plt.show()

# %%
# 4️ Average Screen Time: Weekday vs Weekend

plt.figure(figsize=(7,4))
sns.boxplot(x="Day_Type", y="Avg_Daily_Screen_Time_hr", data=df, palette="Spectral")
plt.title("Average Screen Time: Weekday vs Weekend", fontsize=13, fontweight='bold')
plt.xlabel("Day Type")
plt.ylabel("Average Daily Screen Time (hours)")
plt.show()
# Out:
# /tmp/ipython-input-2844709960.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Day_Type", y="Avg_Daily_Screen_Time_hr", data=df, palette="Spectral")

# %%
# 5️ Screen Time by Age Band (Weekday vs Weekend)

plt.figure(figsize=(8,5))
sns.barplot(x="Age_Band", y="Avg_Daily_Screen_Time_hr", hue="Day_Type", data=df, palette="husl")
plt.title("Screen Time by Age Band (Weekday vs Weekend)", fontsize=13, fontweight='bold')
plt.xlabel("Age Band")
plt.ylabel("Average Screen Time (hours)")
plt.legend(title="Day Type")
plt.show()

# %%
# 6️ Urban vs Rural Screen Time

# Calculate average screen time for Urban vs Rural
avg_screen_time = df.groupby("Urban_or_Rural")["Avg_Daily_Screen_Time_hr"].mean()

# Plot as pie chart
plt.figure(figsize=(6,6))
plt.pie(
    avg_screen_time,
    labels=avg_screen_time.index,
    autopct="%1.1f%%",
    startangle=90,
    colors=sns.color_palette("YlGnBu"),
    wedgeprops={"edgecolor": "black"}
)
plt.title("Average Screen Time Share: Urban vs Rural", fontsize=13, fontweight='bold')
plt.show()

# %%
# 7️ Heatmap – Device vs Age Band

pivot = df.pivot_table(index="Device_Category", columns="Age_Band",
                       values="Avg_Daily_Screen_Time_hr", aggfunc="mean")
plt.figure(figsize=(7,5))
sns.heatmap(pivot, annot=True, cmap="YlOrRd", fmt=".2f", linewidths=0.5)
plt.title("Average Screen Time by Device and Age Band", fontsize=13, fontweight='bold')
plt.xlabel("Age Band")
plt.ylabel("Device Category")
plt.show()

# %%
# 8️ Exceeded Limit by Age Band

plt.figure(figsize=(7,4))
sns.countplot(x="Age_Band", hue="Exceeded_Recommended_Limit", data=df, palette="Set1")
plt.title("Exceeded Screen Time Limit by Age Band", fontsize=13, fontweight='bold')
plt.xlabel("Age Band")
plt.ylabel("Count")
plt.legend(title="Exceeded Limit")
plt.show()

# %%
# 9️ Health Impact Distribution

health_counts = df["Health_Category"].value_counts()
plt.figure(figsize=(6,6))
plt.pie(health_counts, labels=health_counts.index, autopct="%1.1f%%",
        startangle=90, colors=sns.color_palette("viridis", n_colors=len(health_counts)))
plt.title("Health Impact Distribution", fontsize=13, fontweight='bold')
plt.show()

# %% [markdown]
# # OBSERVATION
#
# **Weekend Effect**: Screen time increases significantly on weekends across all age groups.
#
# **Urban vs Rural**: Urban children show higher average daily screen time than rural ones.
#
# **Age Impact**: Teenagers (13–16) and late teens (17–18) are the most active users, often exceeding safe limits.
#
# **Gender Pattern**: Males tend to spend slightly more time on larger devices, while females use a balanced mix.
#
# **Device Preference**: Smaller devices (<30") dominate among pre-teens; older kids use larger screens.
#
# **Health Relation**: Increased screen time correlates with more mental health issues than physical ones.
#
# **Educational Balance**: The educational-to-recreational ratio decreases with age — older kids spend more time on entertainment.
#
# **Peak Usage Cohorts**: Highest usage observed among urban teenagers on weekends.
