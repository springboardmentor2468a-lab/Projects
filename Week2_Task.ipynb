# %% [markdown]
# # Week-1

# %%
# Load the Dataset
import pandas as pd
df = pd.read_csv('Indian_Kids_Screen_Time.csv')
df.head()
# Out:
#    Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0   14    Male                      3.99     Smartphone
# 1   11  Female                      4.61         Laptop
# 2   18  Female                      3.73             TV
# 3   15  Female                      1.21         Laptop
# 4   12  Female                      5.89     Smartphone
#
#    Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                        True                               0.42
# 1                        True                               0.30
# 2                        True                               0.32
# 3                       False                               0.39
# 4                        True                               0.49
#
#            Health_Impacts Urban_or_Rural
# 0  Poor Sleep, Eye Strain          Urban
# 1              Poor Sleep          Urban
# 2              Poor Sleep          Urban
# 3                     NaN          Urban
# ...

# %%
#Check Null values in the Dataset
df.isnull().sum()
# Out:
# Age                                     0
# Gender                                  0
# Avg_Daily_Screen_Time_hr                0
# Primary_Device                          0
# Exceeded_Recommended_Limit              0
# Educational_to_Recreational_Ratio       0
# Health_Impacts                       3218
# Urban_or_Rural                          0
# dtype: int64

# %%
#Check duplicate Values
df.duplicated().sum()
# Out:
# np.int64(44)

# %%
#Check for first 20 Duplicate rows
df[df.duplicated(keep=False)].head(20)
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 369    14    Male                      4.94     Smartphone
# 646    16  Female                      4.42         Laptop
# 672     9  Female                      0.00     Smartphone
# 717    10    Male                      0.00     Smartphone
# 782     9    Male                      0.00     Smartphone
# 968    10  Female                      0.00     Smartphone
# 969     8  Female                      0.00     Smartphone
# 996    16  Female                      4.42         Laptop
# 1099    8  Female                      0.00     Smartphone
# 1172    8  Female                      0.00     Smartphone
# 1177   10    Male                      0.00     Smartphone
# 1387    8  Female                      0.00     Smartphone
# 1419    9    Male                      0.00         Tablet
# 1474   10    Male                      0.00         Tablet
# 1700    9  Female                      0.00     Smartphone
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Dataset
df = pd.read_csv('Indian_Kids_Screen_Time.csv')

# Calculating the correlation
correlation = df.corr(numeric_only=True)

# Heatmap

plt.figure(figsize=(8, 8))
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
#Check info. of the columns in Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9712 entries, 0 to 9711
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                9712 non-null   int64
#  1   Gender                             9712 non-null   object
#  2   Avg_Daily_Screen_Time_hr           9712 non-null   float64
#  3   Primary_Device                     9712 non-null   object
#  4   Exceeded_Recommended_Limit         9712 non-null   bool
#  5   Educational_to_Recreational_Ratio  9712 non-null   float64
#  6   Health_Impacts                     6494 non-null   object
#  7   Urban_or_Rural                     9712 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(4)
# memory usage: 540.7+ KB

# %%
#Check datatype of columns
df.dtypes
# Out:
# Age                                    int64
# Gender                                object
# Avg_Daily_Screen_Time_hr             float64
# Primary_Device                        object
# Exceeded_Recommended_Limit              bool
# Educational_to_Recreational_Ratio    float64
# Health_Impacts                        object
# Urban_or_Rural                        object
# dtype: object

# %%
# Applying discribe function for Statistical analysis 

# For numerical columns
df.describe()
# Out:
#                Age  Avg_Daily_Screen_Time_hr  \
# count  9712.000000               9712.000000
# mean     12.979201                  4.352837
# std       3.162437                  1.718232
# min       8.000000                  0.000000
# 25%      10.000000                  3.410000
# 50%      13.000000                  4.440000
# 75%      16.000000                  5.380000
# max      18.000000                 13.890000
#
#        Educational_to_Recreational_Ratio
# count                        9712.000000
# mean                            0.427226
# std                             0.073221
# min                             0.300000
# 25%                             0.370000
# 50%                             0.430000
# 75%                             0.480000
# max                             0.600000

# %%
# Applying discribe function for Statistical analysis 

# For categorical columns (like Gender, Primary_Device, etc.)
df.describe(include='object')
# Out:
#        Gender Primary_Device Health_Impacts Urban_or_Rural
# count    9712           9712           6494           9712
# unique      2              4             15              2
# top      Male     Smartphone     Poor Sleep          Urban
# freq     4942           4568           2268           6851

# %% [markdown]
# ## OBSERVATIONS
#
# 1. The Health_Impacts column has a significant number of missing values (3,218 missing).
# 2. The dataset contains 44 duplicate rows. These should be removed to prevent bias in the analysis.
# 3. The dataset includes children aged 8 to 18, with the average age being around 13 years.
# 4. df.info() --> Provide Technical summary of the dataset e.g number of rows (Entries),
#    the number of columns, the column names, how many non-null values each column has, and the data type of each columns.
# 5. There is a moderate positive correlation (0.66) between Avg_Daily_Screen_Time_hr and
#    Exceeded_Recommended_Limit (as screen time increases, exceeding the recommended limit also increases).

# %% [markdown]
# # Week-2

# %%
# Load the dataset

import pandas as pd
df = pd.read_csv('Indian_Kids_Screen_Time.csv')
df.head()
# Out:
#    Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0   14    Male                      3.99     Smartphone
# 1   11  Female                      4.61         Laptop
# 2   18  Female                      3.73             TV
# 3   15  Female                      1.21         Laptop
# 4   12  Female                      5.89     Smartphone
#
#    Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                        True                               0.42
# 1                        True                               0.30
# 2                        True                               0.32
# 3                       False                               0.39
# 4                        True                               0.49
#
#            Health_Impacts Urban_or_Rural
# 0  Poor Sleep, Eye Strain          Urban
# 1              Poor Sleep          Urban
# 2              Poor Sleep          Urban
# 3                     NaN          Urban
# ...

# %%
#Check Null values in the Dataset
df.isnull().sum()
# Out:
# Age                                     0
# Gender                                  0
# Avg_Daily_Screen_Time_hr                0
# Primary_Device                          0
# Exceeded_Recommended_Limit              0
# Educational_to_Recreational_Ratio       0
# Health_Impacts                       3218
# Urban_or_Rural                          0
# dtype: int64

# %%
# Replace 'None' with 'No Health Impact'

df['Health_Impacts'] = df['Health_Impacts'].fillna('No Health Impact')
print("Data after replacing 'None':")
df.head()
# Out:
# Data after replacing 'None':
#    Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0   14    Male                      3.99     Smartphone
# 1   11  Female                      4.61         Laptop
# 2   18  Female                      3.73             TV
# 3   15  Female                      1.21         Laptop
# 4   12  Female                      5.89     Smartphone
#
#    Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                        True                               0.42
# 1                        True                               0.30
# 2                        True                               0.32
# 3                       False                               0.39
# 4                        True                               0.49
#
#            Health_Impacts Urban_or_Rural
# 0  Poor Sleep, Eye Strain          Urban
# 1              Poor Sleep          Urban
# 2              Poor Sleep          Urban
# ...

# %%
#Check Null values in the Dataset
df.isnull().sum()
# Out:
# Age                                  0
# Gender                               0
# Avg_Daily_Screen_Time_hr             0
# Primary_Device                       0
# Exceeded_Recommended_Limit           0
# Educational_to_Recreational_Ratio    0
# Health_Impacts                       0
# Urban_or_Rural                       0
# dtype: int64

# %%
# Creating age bands

age_bins = [8, 12, 16, 18] 
age_labels = ['Pre-teen', 'Teenagers', 'Late-teens']
df['Age_Band'] = pd.cut(df['Age'], bins=age_bins, labels=age_labels, right=True, include_lowest=True)

print("\nData with Age Bands:")
df.head()
# Out:
# Data with Age Bands:
#    Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0   14    Male                      3.99     Smartphone
# 1   11  Female                      4.61         Laptop
# 2   18  Female                      3.73             TV
# 3   15  Female                      1.21         Laptop
# 4   12  Female                      5.89     Smartphone
#
#    Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                        True                               0.42
# 1                        True                               0.30
# 2                        True                               0.32
# 3                       False                               0.39
# 4                        True                               0.49
#
#            Health_Impacts Urban_or_Rural    Age_Band
# 0  Poor Sleep, Eye Strain          Urban   Teenagers
# 1              Poor Sleep          Urban    Pre-teen
# ...

# %%
#  categorize health impacts column 
def categorize_health_impact(impact):
    physical_impacts = ['Poor Sleep', 'Eye Strain', 'Obesity Risk']
    mental_impacts = ['Anxiety']
    
    has_physical = any(p in impact for p in physical_impacts)
    has_mental = any(m in impact for m in mental_impacts)
    
    if has_physical and has_mental:
        return 'Physical, Mental Impact'
    elif has_physical:
        return 'Physical Impact'
    elif has_mental:
        return 'Mental Impact'
    else:
        return 'No Health Impact'

df['Health_Category'] = df['Health_Impacts'].apply(categorize_health_impact)

print("\nData with Health Category:")
print(df[['Health_Impacts', 'Health_Category']])
df.head(10)
# Out:
# Data with Health Category:
#                        Health_Impacts          Health_Category
# 0              Poor Sleep, Eye Strain          Physical Impact
# 1                          Poor Sleep          Physical Impact
# 2                          Poor Sleep          Physical Impact
# 3                    No Health Impact         No Health Impact
# 4                 Poor Sleep, Anxiety  Physical, Mental Impact
# ...                               ...                      ...
# 9707                       Poor Sleep          Physical Impact
# 9708                       Poor Sleep          Physical Impact
# 9709  Poor Sleep, Eye Strain, Anxiety  Physical, Mental Impact
# 9710                       Poor Sleep          Physical Impact
# 9711                          Anxiety            Mental Impact
#
# [9712 rows x 2 columns]
#    Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0   14    Male                      3.99     Smartphone
# ...

# %%
df.to_csv('Indian_Kids_Screen_Time_Updated.csv', index=False)
print("Dataset Saved")
# Out:
# Dataset Saved

# %% [markdown]
# ## OBSERVATIONS
#
# 1. Screen time clearly increases with age, with older teens using devices the most.
# 2. Smartphones are the primary device for screen time across all age groups.
# 3. Physical issues like poor sleep and eye strain are common than Mental impact like Anxiety, indicating a tangible impact on children's health.
# 4. screen time increases with age, which showes that the "Teenagers" or "Late-teens" age bands will be the one with the most health impacts.
