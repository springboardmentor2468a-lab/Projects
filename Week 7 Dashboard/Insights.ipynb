# %% [markdown]
# # 📊 Indian Kids Screen Time Analysis Dashboard – Insights
#
# ---
#
# ## 🔹 Overall Summary
# - **Total Kids Surveyed:** 9,712
# - **Average Daily Screen Time:** 4.35 hours
# - **Most Used Device Category:** Portable devices (smartphones/laptops)
# - **Educational to Recreational Usage Ratio:** 0.427 → Recreational use dominates educational purposes
#
# ---
#
# ## 👦👧 Gender Distribution
# - **Males:** 4.77K (≈49%)
# - **Females:** 4.94K (≈51%)
# - Gender ratio is nearly **balanced** among participants
#
# ---
#
# ## ⏰ Exceeded Screen Time Limit
# - **14.4% (≈1.41K kids)** exceed recommended screen time limits
# - **85.6% (≈8.3K kids)** stay within healthy limits
# - Indicates **moderate awareness and control** over screen time habits
#
# ---
#
# ## 📈 Average Screen Time Across Ages
# - **Sharp rise** from age 8 (3.89 hrs) → age 10 (4.50 hrs)
# - From ages **11–18**, screen time remains **stable (4.4–4.5 hrs/day)**
# - Suggests **early adoption** of digital habits maintained through teenage years
#
# ---
#
# ## 🌍 Average Screen Time by Region & Gender
# | Region | Female | Male |
# |:-------|:-------:|:----:|
# | Rural  | 4.4 hrs | 4.3 hrs |
# | Urban  | 4.3 hrs | 4.4 hrs |
#
# - Screen usage is **consistent across gender and region** with minor differences (<0.1 hr)
#
# ---
#
# ## 💻 Device-Based Analysis
# | Device | Daily Screen Time (hrs) | Education Ratio |
# |:--------|:------------------------:|:----------------:|
# | Laptop | 4.5 | 0.4 |
# | Smartphone | 4.4 | 0.4 |
# | TV | 4.4 | 0.4 |
# | Tablet | 4.2 | 0.4 |
#
# - **Laptop users** record the highest screen time
# - **Educational usage constant (0.4)** across all devices
# - **Smartphones and TVs** show significant entertainment influence
#
# ---
#
# ## ❤️ Health Impact by Daily Screen Time
# | Impact Type | Pre-teens | Teenagers | Insight |
# |:-------------|:----------:|:----------:|:---------|
# | Both Physical & Mental | 459 | 892 | Impact rises with age |
# | Mental Only | 626 | 1,320 | **Double increase** among teens |
# | No Impact | 474 | 1,795 | Many teens **report no perceived impact** |
# | Physical Only | 200 | 402 | Physical strain increases with age |
#
# ---
#
# ## 🔍 Key Takeaways
# - **Teenagers dominate** in screen time and experience higher health impacts
# - **Screen time stabilizes** after age 10, showing **early digital exposure**
# - **Portable devices** are the **most preferred**, showing increased accessibility
# - **Educational usage remains low (~40%)**, with **entertainment leading**
# - Despite long screen time, **most kids perceive minimal health issues**, showing **lack of awareness**
# - **Balanced gender ratio** ensures data is demographically fair
#
# ---
#
# ✅ **Conclusion:**
# The dashboard reveals that Indian kids, especially teenagers, spend significant time on screens — primarily for entertainment. While screen usage is evenly spread across gender and regions, mental and physical health impacts increase with age, emphasizing the need for **digital well-being awareness** and **balanced screen habits**.
